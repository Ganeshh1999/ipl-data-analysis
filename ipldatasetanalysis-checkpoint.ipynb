# %%
import pandas as pd

# %%
ipl_matches = pd.read_csv(r'C:\Users\ganesh\Downloads\ipldata\matches.csv')
ipl_matches
# Out:
#         id  season           city        date                        team1  \
# 0        1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1        2    2017           Pune  2017-04-06               Mumbai Indians
# 2        3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3        4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4        5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# ..     ...     ...            ...         ...                          ...
# 751  11347    2019         Mumbai    05/05/19        Kolkata Knight Riders
# 752  11412    2019        Chennai    07/05/19          Chennai Super Kings
# 753  11413    2019  Visakhapatnam    08/05/19          Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam    10/05/19               Delhi Capitals
# 755  11415    2019      Hyderabad    12/05/19               Mumbai Indians
#
# ...

# %% [markdown]
# # RCB vs CSK wins percentages

# %%
df = ipl_matches[((ipl_matches['team1']=="Royal Challengers Bangalore") & (ipl_matches['team2']=="Chennai Super Kings")) | ((ipl_matches['team2']=="Royal Challengers Bangalore") & (ipl_matches['team1']=="Chennai Super Kings"))] 
rcb_wins=df[df['winner']=="Royal Challengers Bangalore"].count()
csk_wins=df[df['winner']=="Chennai Super Kings"].count()
rcb_wins
# Out:
# id                 8
# season             8
# city               8
# date               8
# team1              8
# team2              8
# toss_winner        8
# toss_decision      8
# result             8
# dl_applied         8
# winner             8
# win_by_runs        8
# win_by_wickets     8
# player_of_match    8
# venue              8
# umpire1            8
# umpire2            8
# umpire3            1
# dtype: int64

# %%
import matplotlib.pyplot as plt

# Data to plot
labels = 'rcb', 'csk'
sizes = [rcb_wins['id'], csk_wins['id']]
colors = ['gold', 'lightskyblue']
explode = (0.1, 0)  # explode 1st slice

# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.show()

# %% [markdown]
# # rcb wins against csk (first batting vs first fielding)

# %%
df1 = df[((df['toss_decision']=="bat")&(df['toss_winner']=="Royal Challengers Bangalore"))|((df['toss_winner']=="Chennai Super Kings")&(df['toss_decision']=="field"))]
rcb_wins_bat = df1[df1['winner']=="Royal Challengers Bangalore"].count()
rcb_wins_bat
# Out:
# id                 4
# season             4
# city               4
# date               4
# team1              4
# team2              4
# toss_winner        4
# toss_decision      4
# result             4
# dl_applied         4
# winner             4
# win_by_runs        4
# win_by_wickets     4
# player_of_match    4
# venue              4
# umpire1            4
# umpire2            4
# umpire3            1
# dtype: int64

# %%
import matplotlib.pyplot as plt

# Data to plot
labels = 'rcb_wins_field', 'rcb_wins_bat'
sizes = [rcb_wins['id']- rcb_wins_bat['id'], rcb_wins_bat['id']]
colors = ['gold', 'lightskyblue']
explode = (0.1, 0)  # explode 1st slice

# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.show()

# %% [markdown]
# # analysis the importance of winning the toss

# %%
df = ipl_matches[(ipl_matches['toss_winner']==ipl_matches['winner'])]
df.count()
# Out:
# id                 393
# season             393
# city               390
# date               393
# team1              393
# team2              393
# toss_winner        393
# toss_decision      393
# result             393
# dl_applied         393
# winner             393
# win_by_runs        393
# win_by_wickets     393
# player_of_match    393
# venue              393
# umpire1            391
# umpire2            391
# umpire3             67
# dtype: int64

# %%
# Data to plot
labels = 'toss winner is winner', 'toss winner is loser'
sizes = [df['id'].count(), ipl_matches['id'].count()-df['id'].count()]
colors = ['gold', 'lightskyblue']
explode = (0.1, 0)  # explode 1st slice

# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.show()

# %% [markdown]
# # Rcb choosing after winning the toss

# %%
df1 = ipl_matches[(ipl_matches['toss_winner']=="Royal Challengers Bangalore") & (ipl_matches['toss_decision']=="field")]
df2 = ipl_matches[(ipl_matches['toss_winner']=="Royal Challengers Bangalore") & (ipl_matches['toss_decision']=="bat")]

# %%
# Data to plot
labels = 'rcb choose batting', 'rcb choose fielding'
sizes = [df1['id'].count(),df2['id'].count()]
colors = ['gold', 'lightskyblue']
explode = (0.1, 0)  # explode 1st slice

# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.show()
